# %% [raw]
# ---
# output-file: pickle_training.html
# title: Pickle
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %% [markdown]
# Pickle is a central tool for storing data models.
